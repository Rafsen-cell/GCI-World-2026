# %%
import pandas as pd

# %%
df = pd.read_csv('house_prices.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  str
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  str
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  str
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  str
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  str
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  str
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='str')

# %%
columns_to_drop = ['date', 'waterfront', 'condition']

# %%
df = df.drop(columns=columns_to_drop)

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# sqft_above    -0.010842  0.605567  0.477600   0.685342     0.876597  0.183512
# sqft_basement -0.005151  0.323816  0.303093   0.283770     0.435043  0.015286
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#define X and y
X = df.drop(columns='price')
y = df['price']

#split data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)

#define model
model = LinearRegression()
model.fit(X_train, y_train)

#view scores
print('Training accuracy scores: {:.3f}'.format(model.score(X_train, y_train)))
print('Test accuracy scores: {:.3f}'.format(model.score(X_test, y_test)))

# See how much each feature impacts price
coefficients = pd.DataFrame({
    'Feature'     : X.columns,
    'Coefficient' : model.coef_
})
print(coefficients.sort_values('Coefficient', ascending=False))
print('Intercept:', model.intercept_)
# Out:
# Training accuracy scores: 0.681
# Test accuracy scores: 0.686
#           Feature    Coefficient
# 13            lat  595177.857633
# 7           grade   92300.027863
# 6            view   83153.311864
# 2       bathrooms   41521.609834
# 5          floors    5887.418667
# 3     sqft_living     116.055888
# 8      sqft_above      75.569437
# 9   sqft_basement      40.486451
# 11   yr_renovated      19.477826
# 15  sqft_living15      18.251562
# 4        sqft_lot       0.128991
# 0              id      -0.000001
# 16     sqft_lot15      -0.440288
# 12        zipcode    -626.518174
# 10       yr_built   -2856.817267
# 1        bedrooms  -37182.628163
# 14           long -227995.955279
# Intercept: 10334380.070084058

# %%
#check prediction vs actual
import matplotlib.pyplot as plt

y_pred = model.predict(X_test)

plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted')
plt.plot([y_test.min(), y_test.max()],
         [y_pred.min(), y_pred.max()], 'r--')
plt.show()

# %%
from sklearn.model_selection import cross_val_score

#define X and y
X = df.drop(columns='price')
y = df['price']

#split data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)

#define model
model = LinearRegression()

#perform 4-fold cross validation
scores = cross_val_score(model, X, y, cv=4)

#view scores
print('4-fold cross validation scores: {}'.format(scores))
print('Test accuracy scores: {:.3f}+-{:.3f}'.format(scores.mean(), scores.std()))
# Out:
# 4-fold cross validation scores: [0.66309001 0.67675557 0.6885501  0.68270008]
# Test accuracy scores: 0.678+-0.009

# %%
def homework(anime_data_extracted, X_column, Y_column):
    data = anime_data_extracted
    X_train, X_test, y_train, y_test = train_test_split(data[X_column], data[Y_column], test_size=0.5, random_state=0)
    model = LinearRegression()
    model.fit(X_train, y_train)

    result = model.score(X_test, y_test)
    return result
